# %%
from hl_analysis_module import analyze_health_literacy
result = analyze_health_literacy("some text here ")
import json
print(json.dumps(result, indent=2))
# Out:
# {
#   "profile": "Transitional",
#   "sub_type": "",
#   "hl_level": "Low",
#   "flagged": false,
#   "sigma": 0.1319,
#   "f1": -1.8314,
#   "f2": 0.3083,
#   "f3": 0.414,
#   "suitability": {
#     "Balanced": 19.8,
#     "Transitional": 53.7,
#     "Specialized": 26.5
#   },
#   "raw_scores": {
#     "FHL": 12.2495,
#     "CHL": 0.0,
#     "CRHL": 0.75,
#     "DHL": 0.0,
#     "EHL": 6.734
#   },
#   "clarity_consensus": {
#     "final": 0.2455,
#     "jargon": 0.2045,
#     "explanation": 0.2045,
#     "fluency": 0.0,
#     "coherence": 0.6821,
#     "n_terms": 44,
#     "n_explained": 9,
#     "fre": -12.93,
#     "flagged_transitions": [
#       [
#         "Pdyn+ sympathetic neurons recruited eosinophils through the ",
#         "Our findings reveal a neuroimmunological mechanism underlyin",
#         0.54
#       ]
#     ]
#   },
#   "annotations": {
#     "hl_dimensions": [
#       [
#         "Psychological stress is believed to exacerbate dermatitis, ",
#         null
# ...
